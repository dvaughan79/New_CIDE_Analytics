# %% [markdown]
# # Corrección de la tarea 3:
#
# ##### Solución está online

# %%
import pandas as pd
import numpy as np
resumen = pd.DataFrame(np.zeros((5,3)), columns=['ID_Estudiante','Gist', 'Nota'])
# Números de estudiante
resumen.iloc[:,0] = [1412004,1412024,1211051,1211069,1211037]
# Gist Numbers
resumen.iloc[:,1] = ['nan','nan','nan', 
                     'nan', 'nan']
# Nota
resumen.iloc[:,2] = [8.7,8.5,2.3,8.4,3.4]
resumen
# Out:
#    ID_Estudiante Gist  Nota
# 0        1412004  nan   8.7
# 1        1412024  nan   8.5
# 2        1211051  nan   2.3
# 3        1211069  nan   8.4
# 4        1211037  nan   3.4

# %% [markdown]
# # 1. Estudiante 1:  1412004
#
# 8.7
#
#
# Problema 1: **2.5**
#
# a. 0.5*(0.5)*(10.0/3)
# > Falso: el error se da porque llegó al final de la matriz.  Ver solución.
#
# b. (0.5)*(10.0/3)
#
# -------------------
# Problema 2: **2.91**
#
# a. (0.25)*(10.0/3)
#
# b. (0.25)*(10.0/3)
#
# c. (0.25)*(10.0/3)
#
# d. 0.5*(0.25)*(10.0/3)
# > Interpolación es una opción, pero se le pedía que buscara otro método para hacer exactamente lo mismo que en la parte c.
# -------------------
# Problema 3: **10/3**
#
# a. (0.2)*(10.0/3)
#
# b. (0.2)*(10.0/3)
#
# c. (0.2)*(10.0/3)
#
# d. (0.2)*(10.0/3)
#
# e. (0.2)*(10.0/3)

# %% [markdown]
# # 2. Estudiante 2: 1412024
#
# 8.5
#
# Problema 1:  **3.3**
#
# a. 0.5*(10/3)
#
# b. 0.5*(10/3)
#
# -------------------
# Problema 2: **1.8**
#
# a. (0.25)*(10/3)
#
# b. (0.25)*(10/3):
# > Parte b era sólo reemplazar con indexing por NaNs
#
# c. 0.2*(0.25)*(10/3)
# > Parte c consistía en reemplazar, como en el código de las Notas de Clase, los NaNs con la última observación que tenía presente.  No era llenar NaNs.  Esa era la parte b
#
# d. 0.2*(0.25)*(10/3)
# > Parte d consistía en reemplazar, como en el código de las Notas de Clase, los NaNs con la última observación que tenía presente.  No era llenar NaNs.  Esa era la parte b.  **Ver solución. **
#
# -------------------
# Problema 3: **3.3**
#
# a. (0.2)*(10/3)
#
# b. (0.2)*(10/3)
#
# c. (0.2)*(10/3)
#
# d. (0.2)*(10/3)
#
# e. (0.2)*(10/3)

# %% [markdown]
# # 3. Estudiante 3: 1211051
#
# 2.3
#
# Problema 1 ** 0.33**
#
# a. 0.5*(10/3)*0.1
# > Pudo replicar el error pero no encuentro las respuestas a la parte a y b
#
# b. 0.5*(10/3)*0.1
# > Pudo replicar el error pero no encuentro las respuestas a la parte a y b
#
# -------------------
# Problema 2: **1.7**
#
# a. (0.25)*(10/3)
#
# b. (0.25)*(10/3)
#
# c. 0*(0.25)*(10/3)
# > Tenía que intentarlo con sus datos.  La idea era **adaptar** el método de las Notas en su DF.
#
# d. 0*(0.25)*(10/3)
# > Ver solución.
#
# -------------------
# Problema 3 **0.26**
#
# a. 0.1*(0.2)*(10/3)
# > El objetivo era hacerlo con un loop, asumiendo que no sabe cuántas hojas tiene el archivo, ni sus nombres.  El objetivo era precisamente automatizar lo que hizo hoja por hoja.
#
# b. 0.1*(0.2)*(10/3)
# > El objetivo era hacerlo con un loop, asumiendo que no sabe cuántas hojas tiene el archivo, ni sus nombres.  El objetivo era precisamente automatizar lo que hizo hoja por hoja.
#
# c. 0.1*(0.2)*(10/3)
# > El objetivo era hacerlo con un loop, asumiendo que no sabe cuántas hojas tiene el archivo, ni sus nombres.  El objetivo era precisamente automatizar lo que hizo hoja por hoja.
#
# d. 0.1*(0.2)*(10/3)
# > El objetivo era hacerlo con un loop, asumiendo que no sabe cuántas hojas tiene el archivo, ni sus nombres.  El objetivo era precisamente automatizar lo que hizo hoja por hoja.
#
# e. 0*(0.2)*(10/3)
# > No exportó los datos.

# %% [markdown]
# # 4. Estudiante 4: 1211069
#
# 8.4
#
# Problema 1: **10/3**
#
# a. 0.5*(10/3)
#
# b. 0.5*(10/3)
#
# -------------------
# Problema 2 **10/3**
#
# a. (0.25)*(10/3)
#
# b. (0.25)*(10/3)
#
# c. (0.25)*(10/3)
#
# d. (0.25)*(10/3)
# > Bien: esperaba que programar un método (como en la solución), pero es correcto usar una función preprorgramada
# -------------------
# Problema 3 ** 1.73 **
#
# a. (0.2)*(10/3)
#
# b. 0.2*(0.2)*(10/3)
# > Tenía que hacerlo con un loop.
#
# c. 0.2*(0.2)*(10/3)
# > Tenía que hacerlo con un loop.
#
# d. 0.2*(0.2)*(10/3)
# > Tenía que hacerlo con un loop.
#
# e. (0.2)*(10/3)

# %% [markdown]
# # 5. Estudiante 5:1211037
#
# 3.4
#
# Problema 1: **1.7**
#
# a. (0.5)*(10.0/3)
#
# b. 0*(0.5)*(10.0/3)
# > No veo la solución a la parte b
#
# -------------------
# Problema 2 **1.7**
#
# a. (0.25)*(10.0/3)
#
# b. (0.25)*(10.0/3)
#
# c. 0*(0.25)*(10.0/3)
# > No veo la solución a la parte c
#
# d. 0*(0.25)*(10.0/3)
# > No veo la solución a la parte d
#
# -------------------
# Problema 3 **0**
#
# a. 0*(0.2)*(10.0/3)
# > No veo la solución a la parte a
#
# b. 0*(0.2)*(10.0/3)
# > No veo la solución a la parte b
#
# c. 0*(0.2)*(10.0/3)
# > No veo la solución a la parte c
#
# d. 0*(0.2)*(10.0/3)
# > No veo la solución a la parte d
#
# e. 0*(0.2)*(10.0/3)
# > No veo la solución a la parte e
