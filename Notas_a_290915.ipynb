# %% [markdown]
# # Notas a septiembre 29 2015

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel(u'D:\\Míos\\Clase CIDE\\operativos\\NOtas.xlsx', 'pandas')
data.dropna(subset=['Examen_1'], inplace=True)

# %%
data
# Out:
#     num_estud  Examen_1  Examen1_Curva  Examen_2  Examen_3  Tarea_1  mail_1  \
# 0     1211037      6.35           7.44       NaN       NaN    10.00       1
# 1     1211040      6.15           7.18       NaN       NaN     8.28       1
# 2     1412001      8.15           9.69       NaN       NaN    10.00       1
# 3     1211003      4.60           5.75       NaN       NaN    10.00       1
# 4     1412002      6.30           7.38       NaN       NaN    10.00       1
# 5     1412004      2.75           3.43       NaN       NaN     8.25       1
# 6     1211046      2.50           3.13       NaN       NaN    10.00       1
# 8     1211047      6.45           7.56       NaN       NaN    10.00       1
# 9     1412009      2.80           3.50       NaN       NaN     4.85       1
# 11    1412013      4.00           5.00       NaN       NaN    10.00       1
# 12    1211051      4.95           6.19       NaN       NaN    10.00       1
# ...

# %%
plt.hist(data.Examen1_Curva.dropna())
# Out:
# (array([ 3.,  0.,  3.,  1.,  1.,  2.,  4.,  1.,  1.,  1.]),
#  array([ 3.13 ,  3.786,  4.442,  5.098,  5.754,  6.41 ,  7.066,  7.722,
#          8.378,  9.034,  9.69 ]),
#  <a list of 10 Patch objects>)
